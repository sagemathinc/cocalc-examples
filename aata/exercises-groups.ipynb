# %%
# %%html
# <link href="http://mathbook.pugetsound.edu/beta/mathbook-content.css" rel="stylesheet" type="text/css" />
# <link href="https://aimath.org/mathbook/mathbook-add-on.css" rel="stylesheet" type="text/css" />
# <style>.subtitle {font-size:medium; display:block}</style>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,400italic,600,600italic" rel="stylesheet" type="text/css" />
# <link href="https://fonts.googleapis.com/css?family=Inconsolata:400,700&subset=latin,latin-ext" rel="stylesheet" type="text/css" /><!-- Hide this cell. -->
# <script>
# var cell = $(".container .cell").eq(0), ia = cell.find(".input_area")
# if (cell.find(".toggle-button").length == 0) {
# ia.after(
#     $('<button class="toggle-button">Toggle hidden code</button>').click(
#         function (){ ia.toggle() }
#         )
#     )
# ia.hide()
# }
# </script>

# %% [markdown]
# **Important:** to view this notebook properly you will need to execute the cell above, which assumes you have an Internet connection.  It should already be selected, or place your cursor anywhere above to select.  Then press the "Run" button in the menu bar above (the right-pointing arrowhead), or press Shift-Enter on your keyboard.

# %% [markdown]
# $\newcommand{\identity}{\mathrm{id}}
# \newcommand{\notdivide}{\nmid}
# \newcommand{\notsubset}{\not\subset}
# \newcommand{\lcm}{\operatorname{lcm}}
# \newcommand{\gf}{\operatorname{GF}}
# \newcommand{\inn}{\operatorname{Inn}}
# \newcommand{\aut}{\operatorname{Aut}}
# \newcommand{\Hom}{\operatorname{Hom}}
# \newcommand{\cis}{\operatorname{cis}}
# \newcommand{\chr}{\operatorname{char}}
# \newcommand{\Null}{\operatorname{Null}}
# \newcommand{\lt}{<}
# \newcommand{\gt}{>}
# \newcommand{\amp}{&}
# $

# %% [markdown]
# <div class="mathbook-content"><h2 class="heading hide-type" alt="Exercises 3.4 Exercises"><span class="type">Section</span><span class="codenumber">3.4</span><span class="title">Exercises</span></h2><a href="exercises-groups.ipynb" class="permalink">¶</a></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-71"><h6 class="heading"><span class="codenumber">1</span></h6><p id="p-439">Find all $x \in {\mathbb Z}$ satisfying each of the following equations. </p><ol class="lower-alpha cols2"><li id="li-101"><p id="p-440">$3x \equiv 2 \pmod{7}$</p></li><li id="li-102"><p id="p-441">$5x + 1 \equiv 13 \pmod{23}$</p></li><li id="li-103"><p id="p-442">$5x + 1 \equiv 13 \pmod{26}$</p></li><li id="li-104"><p id="p-443">$9x \equiv 3 \pmod{5}$</p></li><li id="li-105"><p id="p-444">$5x \equiv 1 \pmod{6}$</p></li><li id="li-106"><p id="p-445">$3x \equiv 1 \pmod{6}$</p></li></ol><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-23" id="hint-23"><span class="type">Hint</span></a></span><div id="hk-hint-23" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-446">(a) $3 + 7 \mathbb Z = \{ \ldots, -4, 3, 10, \ldots \}\text{;}$  (c) $18 + 26 \mathbb Z\text{;}$  (e) $5 + 6 \mathbb Z\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-72"><h6 class="heading"><span class="codenumber">2</span></h6><p id="p-447">Which of the following multiplication tables defined on the set $G = \{ a, b, c, d \}$ form a group? Support your answer in each case. </p><ol class="lower-alpha cols2"><li id="li-107"><div class="displaymath" id="p-448">
# \begin{equation*}
# \begin{array}{c|cccc}
# \circ & a & b & c & d \\
# \hline
# a & a & c & d & a \\
# b & b & b & c & d \\
# c & c & d & a & b \\
# d & d & a & b & c
# \end{array}
# \end{equation*}
# </div></li><li id="li-108"><div class="displaymath" id="p-449">
# \begin{equation*}
# \begin{array}{c|cccc}
# \circ & a & b & c & d \\
# \hline
# a & a & b & c & d \\
# b & b & a & d & c \\
# c & c & d & a & b \\
# d & d & c & b & a
# \end{array}
# \end{equation*}
# </div></li><li id="li-109"><div class="displaymath" id="p-450">
# \begin{equation*}
# \begin{array}{c|cccc}
# \circ & a & b & c & d \\
# \hline
# a & a & b & c & d \\
# b & b & c & d & a \\
# c & c & d & a & b \\
# d & d & a & b & c
# \end{array}
# \end{equation*}
# </div></li><li id="li-110"><div class="displaymath" id="p-451">
# \begin{equation*}
# \begin{array}{c|cccc}
# \circ & a & b & c & d \\
# \hline
# a & a & b & c & d \\
# b & b & a & c & d \\
# c & c & b & a & d \\
# d & d & d & b & c
# \end{array}
# \end{equation*}
# </div></li></ol><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-24" id="hint-24"><span class="type">Hint</span></a></span><div id="hk-hint-24" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-452">(a) Not a group; (c) a group.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-groups-rectangle-symmetries"><h6 class="heading"><span class="codenumber">3</span></h6><p id="p-453">Write out Cayley tables for groups formed by the symmetries of a rectangle and for $({\mathbb Z}_4, +)\text{.}$ How many elements are in each group? Are the groups the same? Why or why not?</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-74"><h6 class="heading"><span class="codenumber">4</span></h6><p id="p-454">Describe the symmetries of a rhombus and prove that the set of symmetries forms a group. Give Cayley tables for both the symmetries of a rectangle and the symmetries of a rhombus. Are the symmetries of a rectangle and those of a rhombus the same?</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-75"><h6 class="heading"><span class="codenumber">5</span></h6><p id="p-455">Describe the symmetries of a square and prove that the set of symmetries is a group. Give a Cayley table for the symmetries. How many ways can the vertices of a square be permuted? Is each permutation necessarily a symmetry of the square?  The symmetry group of the square is denoted by $D_4\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-76"><h6 class="heading"><span class="codenumber">6</span></h6><p id="p-456">Give a multiplication table for the group $U(12)\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-25" id="hint-25"><span class="type">Hint</span></a></span><div id="hk-hint-25" class="hidden-content tex2jax_ignore"><span class="solution"><div class="displaymath" id="p-457">
# \begin{equation*}
# \begin{array}{c|cccc}
# \cdot & 1  & 5  & 7  & 11 \\
# \hline
# 1 & 1 & 5 & 7 & 11 \\ 5 & 5 & 1 & 11 & 7 \\
# 7 & 7 & 11 & 1 & 5 \\ 11 & 11 & 7 & 5 & 1
# \end{array}
# \end{equation*}
# </div></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-77"><h6 class="heading"><span class="codenumber">7</span></h6><p id="p-458">Let $S = {\mathbb R} \setminus \{ -1 \}$ and define a binary operation on $S$ by $a \ast b = a + b + ab\text{.}$ Prove that $(S, \ast)$ is an abelian group.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-78"><h6 class="heading"><span class="codenumber">8</span></h6><p id="p-459">Give an example of two elements $A$ and $B$ in $GL_2({\mathbb R})$ with $AB \neq BA\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-26" id="hint-26"><span class="type">Hint</span></a></span><div id="hk-hint-26" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-460">Pick two matrices. Almost any pair will work.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-79"><h6 class="heading"><span class="codenumber">9</span></h6><p id="p-461">Prove that the product of two matrices in $SL_2({\mathbb R})$ has determinant one.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-80"><h6 class="heading"><span class="codenumber">10</span></h6><p id="p-462">Prove that the set of matrices of the form</p><div class="displaymath">
# \begin{equation*}
# \begin{pmatrix}
# 1 & x & y \\
# 0 & 1 & z \\
# 0 & 0 & 1
# \end{pmatrix}
# \end{equation*}
# </div><p>is a group under matrix multiplication. This group, known as the <dfn class="terminology">Heisenberg group</dfn>, is important in quantum physics. Matrix multiplication in the Heisenberg group is defined by</p><div class="displaymath">
# \begin{equation*}
# \begin{pmatrix}
# 1 & x & y \\
# 0 & 1 & z \\
# 0 & 0 & 1
# \end{pmatrix}
# \begin{pmatrix}
# 1 & x' & y' \\
# 0 & 1 & z' \\
# 0 & 0 & 1
# \end{pmatrix}
# =
# \begin{pmatrix}
# 1 & x+x' & y+y'+xz' \\
# 0 & 1 & z+z' \\
# 0 & 0 & 1
# \end{pmatrix}.
# \end{equation*}
# </div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-81"><h6 class="heading"><span class="codenumber">11</span></h6><p id="p-463">Prove that $\det(AB) = \det(A) \det(B)$ in $GL_2({\mathbb R})\text{.}$ Use this result to show that the binary operation in the group $GL_2({\mathbb R})$ is closed; that is, if $A$ and $B$ are in $GL_2({\mathbb R})\text{,}$ then $AB \in GL_2({\mathbb R})\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-82"><h6 class="heading"><span class="codenumber">12</span></h6><p id="p-464">Let ${\mathbb Z}_2^n = \{ (a_1, a_2, \ldots, a_n) : a_i \in {\mathbb Z}_2 \}\text{.}$ Define a binary operation on ${\mathbb Z}_2^n$ by</p><div class="displaymath">
# \begin{equation*}
# (a_1, a_2, \ldots, a_n) + (b_1, b_2, \ldots, b_n) = (a_1 + b_1, a_2 + b_2, \ldots, a_n + b_n).
# \end{equation*}
# </div><p>Prove that ${\mathbb Z}_2^n$ is a group under this operation. This group is important in algebraic coding theory.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-83"><h6 class="heading"><span class="codenumber">13</span></h6><p id="p-465">Show that ${\mathbb R}^{\ast} = {\mathbb R} \setminus \{0 \}$ is a group under the operation of multiplication.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-84"><h6 class="heading"><span class="codenumber">14</span></h6><p id="p-466">Given the groups  ${\mathbb R}^{\ast}$ and ${\mathbb Z}\text{,}$ let $G = {\mathbb R}^{\ast}  \times {\mathbb Z}\text{.}$ Define a binary operation $\circ$ on $G$ by $(a,m) \circ (b,n) = (ab, m + n)\text{.}$ Show that $G$ is a group under this operation.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-85"><h6 class="heading"><span class="codenumber">15</span></h6><p id="p-467">Prove or disprove that every group containing six elements is abelian.</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-27" id="hint-27"><span class="type">Hint</span></a></span><div id="hk-hint-27" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-468">There is a nonabelian group containing six elements.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-86"><h6 class="heading"><span class="codenumber">16</span></h6><p id="p-469">Give a specific example of some group $G$ and elements $g, h \in G$ where $(gh)^n \neq g^nh^n\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-28" id="hint-28"><span class="type">Hint</span></a></span><div id="hk-hint-28" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-470">Look at the symmetry group of an equilateral triangle or a square.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-87"><h6 class="heading"><span class="codenumber">17</span></h6><p id="p-471">Give an example of three different groups with eight elements. Why are the groups different?</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-29" id="hint-29"><span class="type">Hint</span></a></span><div id="hk-hint-29" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-472">The are five different groups of order 8.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-88"><h6 class="heading"><span class="codenumber">18</span></h6><p id="p-473">Show that there are $n!$ permutations of a set containing $n$ items.</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-30" id="hint-30"><span class="type">Hint</span></a></span><div id="hk-hint-30" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-474">Let</p><div class="displaymath">
# \begin{equation*}
# \sigma =
# \begin{pmatrix}
# 1 & 2 & \cdots & n \\ a_1 & a_2 & \cdots & a_n
# \end{pmatrix}
# \end{equation*}
# </div><p>be in $S_n\text{.}$ All of the $a_i$s must be distinct. There are $n$ ways to choose $a_1\text{,}$ $n-1$ ways to choose $a_2\text{,}$ $\ldots\text{,}$ 2 ways to choose $a_{n - 1}\text{,}$ and only one way to choose $a_n\text{.}$ Therefore, we can form $\sigma$ in $n(n - 1) \cdots 2 \cdot 1 = n!$ ways.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-89"><h6 class="heading"><span class="codenumber">19</span></h6><p id="p-475">Show that</p><div class="displaymath">
# \begin{equation*}
# 0 + a  \equiv a + 0  \equiv a \pmod{ n }
# \end{equation*}
# </div><p>for all $a \in {\mathbb Z}_n\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-90"><h6 class="heading"><span class="codenumber">20</span></h6><p id="p-476">Prove that there is  a multiplicative identity for the integers modulo $n\text{:}$</p><div class="displaymath">
# \begin{equation*}
# a \cdot  1   \equiv  a \pmod{n}.
# \end{equation*}
# </div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-91"><h6 class="heading"><span class="codenumber">21</span></h6><p id="p-477">For each $a \in {\mathbb Z}_n$ find an element $b \in {\mathbb Z}_n$ such that</p><div class="displaymath">
# \begin{equation*}
# a + b \equiv b + a  \equiv 0 \pmod{ n}.
# \end{equation*}
# </div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-92"><h6 class="heading"><span class="codenumber">22</span></h6><p id="p-478">Show that addition and multiplication mod $n$ are well defined operations.  That is, show that the operations do not depend on the choice of the representative from the equivalence classes mod $n\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-93"><h6 class="heading"><span class="codenumber">23</span></h6><p id="p-479">Show that addition and multiplication mod $n$ are associative operations.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-94"><h6 class="heading"><span class="codenumber">24</span></h6><p id="p-480">Show that multiplication distributes over addition modulo $n\text{:}$</p><div class="displaymath">
# \begin{equation*}
# a(b  + c)  \equiv ab + ac  \pmod{n}.
# \end{equation*}
# </div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-95"><h6 class="heading"><span class="codenumber">25</span></h6><p id="p-481">Let $a$ and $b$ be elements in a group $G\text{.}$  Prove that $ab^na^{-1} = (aba^{-1})^n$ for $n \in \mathbb Z\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-31" id="hint-31"><span class="type">Hint</span></a></span><div id="hk-hint-31" class="hidden-content tex2jax_ignore"><span class="solution"><div class="displaymath" id="p-482">
# \begin{align*}
# (aba^{-1})^n & = (aba^{-1})(aba^{-1}) \cdots (aba^{-1})\\
# & = ab(aa^{-1})b(aa^{-1})b \cdots b(aa^{-1})ba^{-1}\\
# & = ab^na^{-1}.
# \end{align*}
# </div></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-96"><h6 class="heading"><span class="codenumber">26</span></h6><p id="p-483">Let $U(n)$ be the group of units in ${\mathbb Z}_n\text{.}$ If $n \gt 2\text{,}$ prove that there is an element $k \in U(n)$ such that $k^2 = 1$ and $k \neq 1\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-97"><h6 class="heading"><span class="codenumber">27</span></h6><p id="p-484">Prove that the inverse of $g _1 g_2 \cdots g_n$ is $g_n^{-1} g_{n-1}^{-1} \cdots g_1^{-1}\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-98"><h6 class="heading"><span class="codenumber">28</span></h6><p id="p-485">Prove the remainder of Proposition <a href="section-groups-define.ipynb#proposition-group-equations" class="xref" alt="Proposition 3.21 " title="Proposition 3.21 ">3.21</a>: if $G$ is a group and $a, b \in G\text{,}$ then the equation $xa = b$ has a unique solution in $G\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-99"><h6 class="heading"><span class="codenumber">29</span></h6><p id="p-486">Prove Theorem <a href="section-groups-define.ipynb#theorem-exponent-laws" class="xref" alt="Theorem 3.23 " title="Theorem 3.23 ">3.23</a>.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-100"><h6 class="heading"><span class="codenumber">30</span></h6><p id="p-487">Prove the right and left cancellation laws for a group $G\text{;}$ that is, show that in the group $G\text{,}$ $ba = ca$ implies $b = c$ and $ab = ac$ implies $b = c$ for elements $a, b, c \in G\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-101"><h6 class="heading"><span class="codenumber">31</span></h6><p id="p-488">Show that if $a^2 = e$ for all elements $a$ in a group $G\text{,}$ then $G$ must be abelian.</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-32" id="hint-32"><span class="type">Hint</span></a></span><div id="hk-hint-32" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-489">Since $abab = (ab)^2 = e = a^2 b^2 = aabb\text{,}$ we know that $ba = ab\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-102"><h6 class="heading"><span class="codenumber">32</span></h6><p id="p-490">Show that if $G$ is a finite group of even order, then there is an $a \in G$ such that $a$ is not the identity and $a^2 = e\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-103"><h6 class="heading"><span class="codenumber">33</span></h6><p id="p-491">Let $G$ be a group and suppose that $(ab)^2 = a^2b^2$ for all $a$ and $b$ in $G\text{.}$  Prove that $G$ is an abelian group.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-104"><h6 class="heading"><span class="codenumber">34</span></h6><p id="p-492">Find all the subgroups of ${\mathbb Z}_3 \times {\mathbb Z}_3\text{.}$ Use this information to show that ${\mathbb Z}_3 \times {\mathbb Z}_3$ is not the same group as ${\mathbb Z}_9\text{.}$  (See Example <a href="section-subgroups.ipynb#example-groups-z2xz2" class="xref" alt="Example 3.28 " title="Example 3.28 ">3.28</a>  for a short description of the product of groups.)</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-105"><h6 class="heading"><span class="codenumber">35</span></h6><p id="p-493">Find all the subgroups of the symmetry group of an equilateral triangle.</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-33" id="hint-33"><span class="type">Hint</span></a></span><div id="hk-hint-33" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-494">$H_1 = \{ \identity \}\text{,}$ $H_2 = \{ \identity, \rho_1, \rho_2 \}\text{,}$ $H_3 = \{ \identity, \mu_1 \}\text{,}$ $H_4 = \{ \identity, \mu_2 \}\text{,}$ $H_5 = \{ \identity, \mu_3 \}\text{,}$ $S_3\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-106"><h6 class="heading"><span class="codenumber">36</span></h6><p id="p-495">Compute the subgroups of the symmetry group of a square.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-107"><h6 class="heading"><span class="codenumber">37</span></h6><p id="p-496">Let $H = \{2^k : k \in {\mathbb Z} \}\text{.}$ Show that $H$ is a subgroup of ${\mathbb Q}^*\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-108"><h6 class="heading"><span class="codenumber">38</span></h6><p id="p-497">Let $n = 0, 1, 2, \ldots$ and $n {\mathbb Z} = \{ nk : k \in  {\mathbb Z} \}\text{.}$ Prove that $n {\mathbb Z}$ is a subgroup of ${\mathbb Z}\text{.}$  Show that these subgroups are the only subgroups of $\mathbb{Z}\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-groups-circle-group"><h6 class="heading"><span class="codenumber">39</span></h6><p id="p-498">Let ${\mathbb T} = \{ z \in  {\mathbb C}^* : |z| =1 \}\text{.}$ Prove that ${\mathbb T}$ is a subgroup of ${\mathbb C}^*\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-110"><h6 class="heading"><span class="codenumber">40</span></h6><p id="p-499">Let $G$ consist of the $2 \times 2$ matrices of the form</p><div class="displaymath">
# \begin{equation*}
# \begin{pmatrix}
# \cos \theta & -\sin \theta \\
# \sin \theta & \cos \theta
# \end{pmatrix},
# \end{equation*}
# </div><p>where $\theta \in {\mathbb R}\text{.}$ Prove that $G$ is a subgroup of $SL_2({\mathbb R})\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-111"><h6 class="heading"><span class="codenumber">41</span></h6><p id="p-500">Prove that</p><div class="displaymath">
# \begin{equation*}
# G = \{ a + b \sqrt{2} : a, b \in {\mathbb Q} \text{ and } a \text{ and } b \text{ are not both zero} \}
# \end{equation*}
# </div><p>is a subgroup of ${\mathbb R}^{\ast}$ under the group operation of multiplication.</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-34" id="hint-34"><span class="type">Hint</span></a></span><div id="hk-hint-34" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-501">The identity of $G$ is $1 = 1 + 0 \sqrt{2}\text{.}$ Since $(a + b \sqrt{2}\, )(c + d \sqrt{2}\, ) = (ac + 2bd) + (ad + bc)\sqrt{2}\text{,}$ $G$ is closed under multiplication.  Finally,  $(a + b \sqrt{2}\, )^{-1} = a/(a^2 - 2b^2) - b\sqrt{2}/(a^2 - 2 b^2)\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-112"><h6 class="heading"><span class="codenumber">42</span></h6><p id="p-502">Let $G$ be the group of $2 \times 2$ matrices under addition and</p><div class="displaymath">
# \begin{equation*}
# H =
# \left\{
# \begin{pmatrix}
# a & b \\
# c & d
# \end{pmatrix} :
# a + d = 0
# \right\}.
# \end{equation*}
# </div><p>Prove that $H$ is a subgroup of $G\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-113"><h6 class="heading"><span class="codenumber">43</span></h6><p id="p-503">Prove or disprove: $SL_2( {\mathbb Z} )\text{,}$ the set of $2 \times 2$ matrices with integer entries and determinant one, is a subgroup of $SL_2( {\mathbb R} )\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-114"><h6 class="heading"><span class="codenumber">44</span></h6><p id="p-504">List the subgroups of the quaternion group, $Q_8\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-115"><h6 class="heading"><span class="codenumber">45</span></h6><p id="p-505">Prove that the intersection of two subgroups of a group $G$ is also a subgroup of $G\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-116"><h6 class="heading"><span class="codenumber">46</span></h6><p id="p-506">Prove or disprove:  If $H$ and $K$ are subgroups of a group $G\text{,}$ then $H \cup K$ is a subgroup of $G\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-35" id="hint-35"><span class="type">Hint</span></a></span><div id="hk-hint-35" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-507">Look at $S_3\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-117"><h6 class="heading"><span class="codenumber">47</span></h6><p id="p-508">Prove or disprove: If $H$ and $K$ are subgroups of a group $G\text{,}$ then $H K = \{hk : h \in H \text{ and } k \in K \}$ is a subgroup of $G\text{.}$ What if $G$ is abelian?</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-groups-center-group"><h6 class="heading"><span class="codenumber">48</span></h6><p id="p-509">Let $G$ be a group and $g \in G\text{.}$ Show that</p><div class="displaymath">
# \begin{equation*}
# Z(G) = \{ x \in G : gx = xg \text{ for all } g \in G \}
# \end{equation*}
# </div><p>is a subgroup of $G\text{.}$ This subgroup is called the <dfn class="terminology">center</dfn> of $G\text{.}$ </p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-119"><h6 class="heading"><span class="codenumber">49</span></h6><p id="p-510">Let $a$ and $b$ be elements of a group $G\text{.}$ If $a^4 b = ba$ and $a^3 = e\text{,}$ prove that $ab = ba\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-36" id="hint-36"><span class="type">Hint</span></a></span><div id="hk-hint-36" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-511">$b a = a^4 b = a^3 a b = ab$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-120"><h6 class="heading"><span class="codenumber">50</span></h6><p id="p-512">Give an example of an infinite group in which every nontrivial subgroup is infinite.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-121"><h6 class="heading"><span class="codenumber">51</span></h6><p id="p-513">If $xy = x^{-1} y^{-1}$ for all $x$ and $y$ in $G\text{,}$ prove that $G$ must be abelian.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-122"><h6 class="heading"><span class="codenumber">52</span></h6><p id="p-514">Prove or disprove: Every proper subgroup of an nonabelian group is nonabelian.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-123"><h6 class="heading"><span class="codenumber">53</span></h6><p id="p-515">Let $H$ be a subgroup of $G$ and</p><div class="displaymath">
# \begin{equation*}
# C(H) = \{ g \in G : gh = hg \text{ for all } h \in H \}.
# \end{equation*}
# </div><p>Prove $C(H)$ is a subgroup of $G\text{.}$  This subgroup is called the <dfn class="terminology">centralizer</dfn> of $H$ in $G\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-124"><h6 class="heading"><span class="codenumber">54</span></h6><p id="p-516">Let $H$ be a subgroup of $G\text{.}$  If $g \in G\text{,}$ show that $gHg^{-1} =  \{ghg^{-1} : h\in H\}$ is also a subgroup of $G\text{.}$</p></article></div>
