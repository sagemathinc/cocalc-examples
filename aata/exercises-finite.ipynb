# %%
# %%html
# <link href="http://mathbook.pugetsound.edu/beta/mathbook-content.css" rel="stylesheet" type="text/css" />
# <link href="https://aimath.org/mathbook/mathbook-add-on.css" rel="stylesheet" type="text/css" />
# <style>.subtitle {font-size:medium; display:block}</style>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,400italic,600,600italic" rel="stylesheet" type="text/css" />
# <link href="https://fonts.googleapis.com/css?family=Inconsolata:400,700&subset=latin,latin-ext" rel="stylesheet" type="text/css" /><!-- Hide this cell. -->
# <script>
# var cell = $(".container .cell").eq(0), ia = cell.find(".input_area")
# if (cell.find(".toggle-button").length == 0) {
# ia.after(
#     $('<button class="toggle-button">Toggle hidden code</button>').click(
#         function (){ ia.toggle() }
#         )
#     )
# ia.hide()
# }
# </script>

# %% [markdown]
# **Important:** to view this notebook properly you will need to execute the cell above, which assumes you have an Internet connection.  It should already be selected, or place your cursor anywhere above to select.  Then press the "Run" button in the menu bar above (the right-pointing arrowhead), or press Shift-Enter on your keyboard.

# %% [markdown]
# $\newcommand{\identity}{\mathrm{id}}
# \newcommand{\notdivide}{\nmid}
# \newcommand{\notsubset}{\not\subset}
# \newcommand{\lcm}{\operatorname{lcm}}
# \newcommand{\gf}{\operatorname{GF}}
# \newcommand{\inn}{\operatorname{Inn}}
# \newcommand{\aut}{\operatorname{Aut}}
# \newcommand{\Hom}{\operatorname{Hom}}
# \newcommand{\cis}{\operatorname{cis}}
# \newcommand{\chr}{\operatorname{char}}
# \newcommand{\Null}{\operatorname{Null}}
# \newcommand{\lt}{<}
# \newcommand{\gt}{>}
# \newcommand{\amp}{&}
# $

# %% [markdown]
# <div class="mathbook-content"><h2 class="heading hide-type" alt="Exercises 22.3 Exercises"><span class="type">Section</span><span class="codenumber">22.3</span><span class="title">Exercises</span></h2><a href="exercises-finite.ipynb" class="permalink">¶</a></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-730"><h6 class="heading"><span class="codenumber">1</span></h6><p id="p-3497">Calculate each of the following.</p><ol class="lower-alpha cols2"><li id="li-761"><p id="p-3498">$[\gf(3^6) : \gf(3^3)]$</p></li><li id="li-762"><p id="p-3499">$[\gf(128): \gf(16)]$</p></li><li id="li-763"><p id="p-3500">$[\gf(625) : \gf(25) ]$</p></li><li id="li-764"><p id="p-3501">$[\gf(p^{12}): \gf(p^2)]$</p></li></ol><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-193" id="hint-193"><span class="type">Hint</span></a></span><div id="hk-hint-193" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3502">Make sure that you have a field extension.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-731"><h6 class="heading"><span class="codenumber">2</span></h6><p id="p-3503">Calculate $[\gf(p^m): \gf(p^n)]\text{,}$ where $n \mid m\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-732"><h6 class="heading"><span class="codenumber">3</span></h6><p id="p-3504">What is the lattice of subfields for $\gf(p^{30})\text{?}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-733"><h6 class="heading"><span class="codenumber">4</span></h6><p id="p-3505">Let $\alpha$ be a zero of $x^3 + x^2 + 1$ over ${\mathbb Z}_2\text{.}$ Construct a finite field of order 8. Show that $x^3 + x^2 + 1$ splits in ${\mathbb Z}_2(\alpha)\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-194" id="hint-194"><span class="type">Hint</span></a></span><div id="hk-hint-194" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3506">There are eight elements in ${\mathbb Z}_2(\alpha)\text{.}$ Exhibit two more zeros of $x^3 + x^2 + 1$ other than $\alpha$ in these eight elements.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-734"><h6 class="heading"><span class="codenumber">5</span></h6><p id="p-3507">Construct a finite field of order 27.</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-195" id="hint-195"><span class="type">Hint</span></a></span><div id="hk-hint-195" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3508">Find an irreducible polynomial $p(x)$ in ${\mathbb Z}_3[x]$ of degree 3 and show that ${\mathbb Z}_3[x]/ \langle p(x) \rangle$ has 27 elements.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-735"><h6 class="heading"><span class="codenumber">6</span></h6><p id="p-3509">Prove or disprove: ${\mathbb Q}^\ast$ is cyclic.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-736"><h6 class="heading"><span class="codenumber">7</span></h6><p id="p-3510">Factor each of the following polynomials in ${\mathbb Z}_2[x]\text{.}$ </p><ol class="lower-alpha cols2"><li id="li-765"><p id="p-3511">$x^5- 1$</p></li><li id="li-766"><p id="p-3512">$x^6 + x^5 + x^4 + x^3 + x^2 + x + 1$</p></li><li id="li-767"><p id="p-3513">$x^9 - 1$</p></li><li id="li-768"><p id="p-3514">$x^4 +x^3 + x^2 + x + 1$</p></li></ol><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-196" id="hint-196"><span class="type">Hint</span></a></span><div id="hk-hint-196" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3515">(a) $x^5 -1 = (x+1)(x^4+x^3 + x^2 + x+ 1)\text{;}$ (c) $x^9 -1 = (x+1)( x^2 + x+ 1)(x^6+x^3+1)\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-737"><h6 class="heading"><span class="codenumber">8</span></h6><p id="p-3516">Prove or disprove: ${\mathbb Z}_2[x] / \langle x^3 + x + 1 \rangle \cong {\mathbb Z}_2[x] / \langle x^3 + x^2 + 1 \rangle\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-197" id="hint-197"><span class="type">Hint</span></a></span><div id="hk-hint-197" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3517">True.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-738"><h6 class="heading"><span class="codenumber">9</span></h6><p id="p-3518">Determine the number of cyclic codes of length $n$ for $n = 6\text{,}$ 7, 8, 10.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-739"><h6 class="heading"><span class="codenumber">10</span></h6><p id="p-3519">Prove that the ideal $\langle t + 1 \rangle$ in $R_n$ is the code in ${\mathbb Z}_2^n$ consisting of all words of even parity.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-740"><h6 class="heading"><span class="codenumber">11</span></h6><p id="p-3520">Construct all <abbr class="acronym">BCH</abbr> codes of </p><ol class="lower-alpha cols2"><li id="li-769"><p id="p-3521">length 7.</p></li><li id="li-770"><p id="p-3522">length 15.</p></li></ol><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-198" id="hint-198"><span class="type">Hint</span></a></span><div id="hk-hint-198" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3523">(a) Use the fact that $x^7 -1 = (x+1)( x^3 + x+ 1)(x^3+x^2+1)\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-741"><h6 class="heading"><span class="codenumber">12</span></h6><p id="p-3524">Prove or disprove: There exists a finite field that is algebraically closed.</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-199" id="hint-199"><span class="type">Hint</span></a></span><div id="hk-hint-199" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3525">False.</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-742"><h6 class="heading"><span class="codenumber">13</span></h6><p id="p-3526">Let $p$ be prime.  Prove that the field of rational functions ${\mathbb Z}_p(x)$ is an infinite field of characteristic $p\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-743"><h6 class="heading"><span class="codenumber">14</span></h6><p id="p-3527">Let $D$ be an integral domain of characteristic $p\text{.}$  Prove that $(a - b)^{p^n} = a^{p^n} - b^{p^n}$ for all $a, b \in D\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-finite-sum-of-squares"><h6 class="heading"><span class="codenumber">15</span></h6><p id="p-3528">Show that every element in a finite field can be written as the sum of two squares.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-745"><h6 class="heading"><span class="codenumber">16</span></h6><p id="p-3529">Let $E$ and $F$ be subfields of a finite field $K\text{.}$ If $E$ is isomorphic to $F\text{,}$ show that $E=F\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-746"><h6 class="heading"><span class="codenumber">17</span></h6><p id="p-3530">Let $F \subset E \subset K$ be fields. If $K$ is a separable extension of $F\text{,}$ show that $K$ is also separable extension of $E\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-200" id="hint-200"><span class="type">Hint</span></a></span><div id="hk-hint-200" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3531">If $p(x) \in F[x]\text{,}$ then $p(x) \in E[x]\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-747"><h6 class="heading"><span class="codenumber">18</span></h6><p id="p-3532">Let $E$ be an extension of a finite field $F\text{,}$ where $F$ has $q$ elements. Let $\alpha \in E$ be algebraic over $F$ of degree $n\text{.}$ Prove that $F( \alpha )$ has $q^n$ elements.</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-201" id="hint-201"><span class="type">Hint</span></a></span><div id="hk-hint-201" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3533">Since $\alpha$ is algebraic over $F$ of degree $n\text{,}$ we can write any element $\beta \in F(\alpha)$ uniquely as $\beta = a_0  + a_1 \alpha + \cdots + a_{n-1} \alpha^{n-1}$ with $a_i \in F\text{.}$ There are $q^n$ possible $n$-tuples $(a_0, a_1, \ldots, a_{n-1})\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-748"><h6 class="heading"><span class="codenumber">19</span></h6><p id="p-3534">Show that every finite extension of a finite field $F$ is simple; that is, if $E$ is a finite extension of a finite field $F\text{,}$ prove that there exists an $\alpha \in E$ such that $E = F( \alpha )\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-749"><h6 class="heading"><span class="codenumber">20</span></h6><p id="p-3535">Show that for every $n$ there exists an irreducible polynomial of degree $n$ in ${\mathbb Z}_p[x]\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-frobenius-map"><h6 class="heading"><span class="codenumber">21</span></h6><p id="p-3536">Prove that the <dfn class="terminology">Frobenius map</dfn> $\Phi : \gf(p^n) \rightarrow \gf(p^n)$ given by $\Phi : \alpha \mapsto \alpha^p$ is an automorphism of order $n\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-751"><h6 class="heading"><span class="codenumber">22</span></h6><p id="p-3537">Show that every element in $\gf(p^n)$ can be written in the form $a^p$ for some unique $a \in \gf(p^n)\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-752"><h6 class="heading"><span class="codenumber">23</span></h6><p id="p-3538">Let $E$ and $F$ be subfields of $\gf(p^n)\text{.}$ If $|E| = p^r$ and $|F| = p^s\text{,}$ what is the order of $E \cap F\text{?}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-753"><h6 class="heading"><span class="codenumber">24</span><span class="title">Wilson's Theorem</span></h6><p id="p-3539">Let $p$ be prime.  Prove that $(p-1)! \equiv -1 \pmod{p}\text{.}$</p><div class="solutions"><span class="solution"><a knowl="" class="id-ref" refid="hk-hint-202" id="hint-202"><span class="type">Hint</span></a></span><div id="hk-hint-202" class="hidden-content tex2jax_ignore"><span class="solution"><p id="p-3540">Factor $x^{p-1} - 1$ over ${\mathbb Z}_p\text{.}$</p></span></div></div></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-754"><h6 class="heading"><span class="codenumber">25</span></h6><p id="p-3541">If $g(t)$ is the minimal generator polynomial for a cyclic code $C$ in $R_n\text{,}$ prove that the constant term of $g(x)$ is $1\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-755"><h6 class="heading"><span class="codenumber">26</span></h6><p id="p-3542">Often it is conceivable that a burst of errors might occur during transmission, as in the case of a power surge.  Such a momentary burst of interference might alter several consecutive bits in a codeword. Cyclic codes permit the detection of such error bursts. Let $C$ be an $(n,k)$-cyclic code. Prove that any error burst up to $n-k$ digits can be detected.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-756"><h6 class="heading"><span class="codenumber">27</span></h6><p id="p-3543">Prove that the rings $R_n$ and ${\mathbb Z}_2^n$ are isomorphic as vector spaces.</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-757"><h6 class="heading"><span class="codenumber">28</span></h6><p id="p-3544">Let $C$ be a code in $R_n$ that is generated by $g(t)\text{.}$ If $\langle f(t) \rangle$ is another code in $R_n\text{,}$ show that $\langle g(t) \rangle \subset \langle f(t) \rangle$ if and only if $f(x)$ divides $g(x)$ in ${\mathbb Z}_2[x]\text{.}$</p></article></div>

# %% [markdown]
# <div class="mathbook-content"></div>

# %% [markdown]
# <div class="mathbook-content"><article class="exercise-like" id="exercise-758"><h6 class="heading"><span class="codenumber">29</span></h6><p id="p-3545">Let $C = \langle g(t) \rangle$ be a cyclic code in $R_n$ and suppose that $x^n - 1 = g(x) h(x)\text{,}$ where $g(x) = g_0 + g_1 x + \cdots + g_{n - k} x^{n - k}$ and $h(x) = h_0 + h_1 x +  \cdots + h_k x^k\text{.}$ Define $G$ to be the $n \times k$ matrix</p><div class="displaymath">
# \begin{equation*}
# G =
# \begin{pmatrix}
# g_0 & 0   & \cdots & 0 \\
# g_1 & g_0 & \cdots & 0 \\
# \vdots & \vdots &\ddots & \vdots \\
# g_{n-k}   & g_{n-k-1} & \cdots & g_0 \\
# 0   & g_{n-k} & \cdots & g_{1} \\
# \vdots & \vdots & \ddots & \vdots \\
# 0   & 0 & \cdots & g_{n-k}
# \end{pmatrix}
# \end{equation*}
# </div><p>and $H$ to be the $(n-k) \times n$ matrix</p><div class="displaymath">
# \begin{equation*}
# H =
# \begin{pmatrix}
# 0   & \cdots & 0   & 0      & h_k    & \cdots & h_0 \\
# 0   & \cdots & 0   & h_k    & \cdots & h_0    & 0 \\
# \cdots & \cdots & \cdots  & \cdots & \cdots & \cdots & \cdots  \\
# h_k & \cdots & h_0 & 0      & 0      & \cdots & 0
# \end{pmatrix}.
# \end{equation*}
# </div><ol class="lower-alpha"><li id="li-771"><p id="p-3546">Prove that $G$ is a generator matrix for $C\text{.}$</p></li><li id="li-772"><p id="p-3547">Prove that $H$ is a parity-check matrix for $C\text{.}$</p></li><li id="li-773"><p id="p-3548">Show that $HG = 0\text{.}$</p></li></ol></article></div>
